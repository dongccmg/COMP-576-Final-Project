# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tmp = np.load('drive/MyDrive/dataset/train_val/candidate1.npz')

# %%
tmp['voxel']
# Out:
# array([[[187, 192, 190, ...,  12,  34,  15],
#         [192, 191, 194, ...,   1,  19,  32],
#         [189, 193, 191, ...,   3,   0,  26],
#         ...,
#         [140, 189, 198, ..., 167, 163, 165],
#         [173, 206, 207, ..., 165, 168, 177],
#         [150, 190, 186, ..., 167, 167, 186]],
#
#        [[194, 194, 193, ...,   9,  34,  17],
#         [198, 190, 192, ...,   1,  16,  31],
#         [195, 190, 190, ...,   3,   0,  18],
#         ...,
#         [123, 173, 184, ..., 166, 162, 169],
#         [163, 194, 202, ..., 166, 167, 175],
#         [159, 196, 198, ..., 170, 169, 178]],
#
#        [[194, 190, 191, ...,   7,  33,  19],
#         [195, 188, 193, ...,   0,  10,  30],
#         [193, 193, 190, ...,   4,   0,  12],
#         ...,
#         [ 98, 151, 162, ..., 164, 165, 169],
#         [146, 177, 196, ..., 165, 165, 170],
#         [150, 201, 204, ..., 167, 168, 172]],
#
#        ...,
#
#        [[138, 110,  45, ..., 165, 168, 183],
# ...

# %%
tmp['seg']
# Out:
# array([[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
# ...

# %%
np.shape(tmp['voxel'])
# Out:
# (100, 100, 100)

# %%
np.shape(tmp['seg'])
# Out:
# (100, 100, 100)

# %%
voxel = tmp['voxel']/255
seg = tmp['seg']

# %%
for i in range(37,60,2):
    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(seg[i])
    plt.subplot(1,2,2)
    plt.imshow(voxel[i])
    plt.show()
